# %%
import sqlite3
import numpy as np
import pandas as pd

# %%
def create_question_response_table() -> tuple:
    csv_file_path = "kaggle_survey_2022_responses.csv"
    first_two_lines = pd.read_csv(csv_file_path, nrows=1)
    temp_df = pd.read_csv(csv_file_path, skiprows=[1], low_memory=False)
    survey_data = temp_df.drop('Duration (in seconds)', axis=1)
    question_indices = [col_name[0] for col_name in survey_data.columns.str.split("_")]
    question_descriptions = first_two_lines.values.ravel()[1:]
    unique_question_indices = pd.Series(question_indices).unique()
    question_descriptions_split = [desc.split(" - ")[0] for desc in question_descriptions]
    unique_question_descriptions = pd.Series(question_descriptions_split).unique()
    question_types = ["Multiple Response" if "(Select all that apply)" in desc else "Multiple Choice" for desc in unique_question_descriptions]
    question_table = pd.DataFrame()
    question_table["id"] = np.arange(1, unique_question_indices.size + 1)
    question_table["question_index"] = unique_question_indices
    question_table["type"] = question_types
    question_table["description"] = unique_question_descriptions
    n_rows = survey_data.shape[0]
    survey_data.insert(0, "id", np.arange(1, n_rows + 1))
    response_table = pd.melt(survey_data, id_vars="id", var_name="question_index", value_name="response").dropna()
    question_indices = [qi[0] for qi in response_table["question_index"].str.split("_")]
    response_table["question_index"] = question_indices
    merge_response_question_table = pd.merge(response_table, question_table[["id", "question_index"]], left_on="question_index", right_on="question_index")
    response_table = merge_response_question_table[["id_x", "id_y", "response"]]
    response_table.columns = ["respondant_id", "question_id", "choice"]
    return question_table, response_table

# %%
questions, responses = create_question_response_table()

# %%
questions
# Out:
#     id question_index               type  \
# 0    1             Q2    Multiple Choice
# 1    2             Q3    Multiple Choice
# 2    3             Q4    Multiple Choice
# 3    4             Q5    Multiple Choice
# 4    5             Q6  Multiple Response
# 5    6             Q7  Multiple Response
# 6    7             Q8    Multiple Choice
# 7    8             Q9    Multiple Choice
# 8    9            Q10    Multiple Choice
# 9   10            Q11    Multiple Choice
# 10  11            Q12  Multiple Response
# 11  12            Q13  Multiple Response
# 12  13            Q14  Multiple Response
# 13  14            Q15  Multiple Response
# 14  15            Q16    Multiple Choice
# 15  16            Q17  Multiple Response
# 16  17            Q18  Multiple Response
# 17  18            Q19  Multiple Response
# 18  19            Q20  Multiple Response
# 19  20            Q21  Multiple Response
# 20  21            Q22    Multiple Choice
# 21  22            Q23    Multiple Choice
# 22  23            Q24    Multiple Choice
# 23  24            Q25    Multiple Choice
# 24  25            Q26    Multiple Choice
# 25  26            Q27    Multiple Choice
# 26  27            Q28  Multiple Response
# 27  28            Q29    Multiple Choice
# 28  29            Q30    Multiple Choice
# 29  30            Q31  Multiple Response
# 30  31            Q32    Multiple Choice
# 31  32            Q33  Multiple Response
# 32  33            Q34  Multiple Response
# 33  34            Q35  Multiple Response
# 34  35            Q36  Multiple Response
# 35  36            Q37  Multiple Response
# 36  37            Q38  Multiple Response
# 37  38            Q39  Multiple Response
# 38  39            Q40  Multiple Response
# 39  40            Q41  Multiple Response
# 40  41            Q42  Multiple Response
# 41  42            Q43    Multiple Choice
# 42  43            Q44  Multiple Response
#
#                                           description
# 0                         What is your age (# years)?
# 1                                What is your gender?
# 2           In which country do you currently reside?
# 3   Are you currently a student? (high school, uni...
# 4   On which platforms have you begun or completed...
# 5   What products or platforms did you find to be ...
# 6   What is the highest level of formal education ...
# 7   Have you ever published any academic research ...
# 8     Did your research make use of machine learning?
# 9   For how many years have you been writing code ...
# 10  What programming languages do you use on a reg...
# 11  Which of the following integrated development ...
# 12  Do you use any of the following hosted noteboo...
# 13  Do you use any of the following data visualiza...
# 14  For how many years have you used machine learn...
# 15  Which of the following machine learning framew...
# 16  Which of the following ML algorithms do you us...
# 17  Which categories of computer vision methods do...
# 18  Which of the following natural language proces...
# 19  Do you download pre-trained model weights from...
# 20  Which of the following ML model hubs/repositor...
# 21  Select the title most similar to your current ...
# 22  In what industry is your current employer/cont...
# 23  What is the size of the company where you are ...
# 24  Approximately how many individuals are respons...
# 25  Does your current employer incorporate machine...
# 26  Select any activities that make up an importan...
# 27  What is your current yearly compensation (appr...
# 28  Approximately how much money have you spent on...
# 29  Which of the following cloud computing platfor...
# 30  Of the cloud platforms that you are familiar w...
# 31  Do you use any of the following cloud computin...
# 32  Do you use any of the following data storage p...
# 33  Do you use any of the following data products ...
# 34  Do you use any of the following business intel...
# 35  Do you use any of the following managed machin...
# 36  Do you use any of the following automated mach...
# 37  Do you use any of the following products to se...
# 38  Do you use any tools to help monitor your mach...
# 39  Do you use any of the following responsible or...
# 40  Do you use any of the following types of speci...
# 41  Approximately how many times have you used a T...
# 42  Who/what are your favorite media sources that ...

# %%
responses
# Out:
#         respondant_id  question_id choice
# 0                   1            1  30-34
# 1                   2            1  30-34
# 2                   3            1  18-21
# 3                   4            1  55-59
# 4                   5            1  45-49
# ...               ...          ...    ...
# 834427          23815           43  Other
# 834428          23839           43  Other
# 834429          23987           43  Other
# 834430          23989           43  Other
# 834431          23997           43  Other
#
# [834432 rows x 3 columns]

# %%
con = sqlite3.connect('KaggleSurvey2022.db')
questions.to_sql('questions', con, if_exists='replace', index=False)
responses.to_sql('responses', con, if_exists='replace', index=False)
cur = con.cursor()

# %%
create_questions = """
PRAGMA foreign_keys=off;
BEGIN TRANSACTION;
ALTER TABLE questions RENAME TO questions_no_keys;
CREATE TABLE questions (
    id INTEGER,
    question_index INTEGER,
    type TEXT,
    description TEXT,
    PRIMARY KEY (id)
);
INSERT INTO questions SELECT * FROM questions_no_keys;
COMMIT;
PRAGMA foreign_keys=on;
"""
cur.executescript(create_questions)
con.commit()

# %%
create_responses = """
PRAGMA foreign_keys=off;
BEGIN TRANSACTION;
ALTER TABLE responses RENAME TO responses_no_keys;
CREATE TABLE responses (
    respondant_id INTEGER,
    question_id INTEGER,
    choice TEXT,
    FOREIGN KEY (question_id) REFERENCES questions (id) 
            ON DELETE CASCADE ON UPDATE NO ACTION
);
INSERT INTO responses SELECT * FROM responses_no_keys;
COMMIT;
PRAGMA foreign_keys=on;
"""
cur.executescript(create_responses)
con.commit()

# %%
drop_tables = """
DROP TABLE questions_no_keys;
DROP TABLE responses_no_keys;
"""
cur.executescript(drop_tables)
con.commit()

# %%
con.close()
